# %%
import pandas as pd

# %%
df_train_set_ocr = pd.read_json('../../data/hackathon/train_set_ocr.json', typ='series')

# %%
df_train_set_ocr.head()
# Out:
# test_hashed\pit37_v1\9d6f61c6-52ad-4546-85b7-b6a0a30a21d5.jpg    POLA Lalwe poda PODATNIK POLA , CIEMNE _ URZAD...
# test_hashed\pit37_v1\f14ea197-70bd-45ae-9a22-d243f37f6c26.jpg    PlTaxpl POUA 'WYPELNIA PODATNIK POLA CIEMNE WY...
# test_hashed\pit37_v1\070a521a-7038-4551-bc6a-bbb6f96e1505.jpg    MyPfenl Wypelnic DulyMi DaukowanlUiTERAM ClRnY...
# test_hashed\pit37_v1\f4d15b30-6e96-4452-b614-a986065d6a80.jpg    PlTaxpl POLA JASNE WYPEŁNIA PODATNIK _POLA CIE...
# test_hashed\pit37_v1\64d085a8-39a0-4887-859e-811a3de9879b.jpg    PITaxpl LA Jash€ WyPelNIA PODiTŃIK PCU CieMne ...
# dtype: object

# %%
df_train_set_ocr = df_train_set_ocr.reset_index()

# %%
df_train_set_ocr.head()
# Out:
#                                                index  \
# 0  test_hashed\pit37_v1\9d6f61c6-52ad-4546-85b7-b...
# 1  test_hashed\pit37_v1\f14ea197-70bd-45ae-9a22-d...
# 2  test_hashed\pit37_v1\070a521a-7038-4551-bc6a-b...
# 3  test_hashed\pit37_v1\f4d15b30-6e96-4452-b614-a...
# 4  test_hashed\pit37_v1\64d085a8-39a0-4887-859e-8...
#
#                                                    0
# 0  POLA Lalwe poda PODATNIK POLA , CIEMNE _ URZAD...
# 1  PlTaxpl POUA 'WYPELNIA PODATNIK POLA CIEMNE WY...
# 2  MyPfenl Wypelnic DulyMi DaukowanlUiTERAM ClRnY...
# 3  PlTaxpl POLA JASNE WYPEŁNIA PODATNIK _POLA CIE...
# 4  PITaxpl LA Jash€ WyPelNIA PODiTŃIK PCU CieMne ...

# %%
df_train_set_ocr.rename(columns={'index': 'file', 0: 'text'}, inplace=True)

# %%
df_train_set_ocr.head()
# Out:
#                                                 file  \
# 0  test_hashed\pit37_v1\9d6f61c6-52ad-4546-85b7-b...
# 1  test_hashed\pit37_v1\f14ea197-70bd-45ae-9a22-d...
# 2  test_hashed\pit37_v1\070a521a-7038-4551-bc6a-b...
# 3  test_hashed\pit37_v1\f4d15b30-6e96-4452-b614-a...
# 4  test_hashed\pit37_v1\64d085a8-39a0-4887-859e-8...
#
#                                                 text
# 0  POLA Lalwe poda PODATNIK POLA , CIEMNE _ URZAD...
# 1  PlTaxpl POUA 'WYPELNIA PODATNIK POLA CIEMNE WY...
# 2  MyPfenl Wypelnic DulyMi DaukowanlUiTERAM ClRnY...
# 3  PlTaxpl POLA JASNE WYPEŁNIA PODATNIK _POLA CIE...
# 4  PITaxpl LA Jash€ WyPelNIA PODiTŃIK PCU CieMne ...

# %%
df_train_labels_final = pd.read_json('../../data/hackathon/train_labels_final.json', typ='series')

# %%
df_train_labels_final = df_train_labels_final.reset_index()

# %%
df_train_labels_final.head()
# Out:
#                                                index         0
# 0  test_hashed\pit37_v1\9d6f61c6-52ad-4546-85b7-b...  pit37_v1
# 1  test_hashed\pit37_v1\f14ea197-70bd-45ae-9a22-d...  pit37_v1
# 2  test_hashed\pit37_v1\070a521a-7038-4551-bc6a-b...  pit37_v1
# 3  test_hashed\pit37_v1\f4d15b30-6e96-4452-b614-a...  pit37_v1
# 4  test_hashed\pit37_v1\64d085a8-39a0-4887-859e-8...  pit37_v1

# %%
df_train_labels_final.rename(columns={'index': 'file', 0: 'label'}, inplace=True)

# %%
pd.merge(df_train_set_ocr, df_train_labels_final, on='file', how='outer')
# Out:
#                                                     file  \
# 0      test_hashed\pit37_v1\9d6f61c6-52ad-4546-85b7-b...
# 1      test_hashed\pit37_v1\f14ea197-70bd-45ae-9a22-d...
# 2      test_hashed\pit37_v1\070a521a-7038-4551-bc6a-b...
# 3      test_hashed\pit37_v1\f4d15b30-6e96-4452-b614-a...
# 4      test_hashed\pit37_v1\64d085a8-39a0-4887-859e-8...
# ...                                                  ...
# 10879  ./test_hashed/specification/8a1bb716-156c-4eca...
# 10880  ./test_hashed/specification/e42169d6-f1c4-416a...
# 10881  ./test_hashed/form/9807fe93-30d5-422b-8844-fd1...
# 10882  ./test_hashed/handwritten/e7eac2d5-364d-4f82-b...
# 10883  ./test_hashed/advertisement/143d2d22-378e-4595...
#
#                                                     text          label
# 0      POLA Lalwe poda PODATNIK POLA , CIEMNE _ URZAD...       pit37_v1
# 1      PlTaxpl POUA 'WYPELNIA PODATNIK POLA CIEMNE WY...       pit37_v1
# ...

# %%
df_test_set_ocr = pd.read_json('../../data/hackathon/test_ocr_clean.json', typ='series')

# %%
df_test_set_ocr = df_test_set_ocr.reset_index()

# %%
df_test_set_ocr.rename(columns={'index': 'file', 0: 'text'}, inplace=True)

# %%
df_test_set_ocr.head()
# Out:
#                                                 file  \
# 0  test_set/e9fdc30e-99bd-4df8-ac68-adab008dfc88.jpg
# 1  test_set/1131d492-9670-4cf3-876b-d7d63fdb93cf.jpg
# 2  test_set/a10b2b27-b827-417c-8158-87c607516275.jpg
# 3  test_set/f72c1791-2966-4751-885a-f8575b529811.jpg
# 4  test_set/3acc02fa-164e-43d2-899a-82f16ef56dd8.jpg
#
#                                                 text
# 0  PITaxpl POLALSHPein 9220067289 8383511524 18 1...
# 1  Kooaek DalkoNana LiteRAV CZARNYM LLB NeBiesAV ...
# 2  Wypelnv Joonn Beyffenl Vazar FLENY Plsfl Delko...
# 3  PlTaxpl POLA JASNE WYPELN4 PoDATnIK POLA CieMN...
# 4  PlTaxpl POL A JASNE WypelNIA PodaTNix CienncKy...

# %% [markdown]
# ## CV na dokumentach

# %% [markdown]
# ### Modelowanie

# %%
import tensorflow as tf
# Out:
# c:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
import os 
from PIL import Image
import numpy as np
import pandas as pd
import cv2

dirname = '../../data/datasets/test_set/'
df_test = []
for fname in os.listdir(dirname):
    try:
        im = Image.open(os.path.join(dirname, fname))
    except:
        continue
    imarray = np.array(im)
    new_array = cv2.resize(imarray, (1000, 754)) # (1000, 754) najczęściej występujący rozmiar obrazków w train
    df_test.append([new_array])

df_test
# Out:
# [[array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#  [array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
#  [array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)],
# ...

# %%
labels = {"0": "advertisement", "1": "budget", "2": "email", "3": "file_folder", "4": "form", "5": "handwritten", "6": "invoice", "7": "letter", "8": "memo", "9": "news_article", "10": "pit37_v1", "11": "pozwolenie_uzytkowanie_obiektu_budowlanego", "12": "presentation", "13": "questionnaire", "14": "resume", "15": "scientific_publication", "16": "scientific_report", "17": "specification", "18": "umowa_na_odleglosc_odstapienie", "19": "umowa_o_dzielo", "20": "umowa_sprzedazy_samochodu"}

# %%
categories = list(labels.values())

# %%
import os 
from PIL import Image
import numpy as np
import pandas as pd
import cv2

dirname = '../../data/datasets/train_set/'
df_train = []
for category in categories:
    new_path = os.path.join(dirname, category) + "/"
    class_num = categories.index(category)
    for fname in os.listdir(new_path):
        im = Image.open(os.path.join(new_path, fname))
        imarray = np.array(im)
        new_array = cv2.resize(imarray, (1000, 754))
        df_train.append([new_array, class_num])

# %%
df_train
# Out:
# [[array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   0],
#  [array([[ 56,  58,  63, ...,   1,   0,   0],
#          [153, 198, 233, ...,  13,   0,   0],
#          [239, 249, 253, ...,   7,   0,   0],
#          ...,
#          [139, 188, 232, ..., 215, 235, 246],
#          [111, 143, 203, ..., 154, 148, 185],
#          [123, 116, 156, ...,  28,  26,  28]], dtype=uint8),
#   0],
#  [array([[  0,   0,   0, ...,   0,   0,   0],
#          [  0,   4,   5, ...,   0,   0,   0],
#          [139, 163, 170, ...,   0,   0,   0],
#          ...,
#          [255, 255, 255, ...,   0,   0,   0],
#          [255, 255, 255, ...,   0,   0,   0],
#          [255, 255, 255, ...,   0,   0,   0]], dtype=uint8),
#   0],
# ...

# %%
df_train
# Out:
# [[array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   0],
#  [array([[ 56,  58,  63, ...,   1,   0,   0],
#          [153, 198, 233, ...,  13,   0,   0],
#          [239, 249, 253, ...,   7,   0,   0],
#          ...,
#          [139, 188, 232, ..., 215, 235, 246],
#          [111, 143, 203, ..., 154, 148, 185],
#          [123, 116, 156, ...,  28,  26,  28]], dtype=uint8),
#   0],
#  [array([[  0,   0,   0, ...,   0,   0,   0],
#          [  0,   4,   5, ...,   0,   0,   0],
#          [139, 163, 170, ...,   0,   0,   0],
#          ...,
#          [255, 255, 255, ...,   0,   0,   0],
#          [255, 255, 255, ...,   0,   0,   0],
#          [255, 255, 255, ...,   0,   0,   0]], dtype=uint8),
#   0],
# ...

# %%
X = []
y = []
for features, classes in df_train:
    X.append(features)
    y.append(classes)

# %%
X = pd.Series(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)
